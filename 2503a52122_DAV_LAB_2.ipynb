# %% [markdown]
# <a href="https://colab.research.google.com/github/2503a52122/SALONI/blob/main/2503a52122_DAV_LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/earthquake_1995-2023 (1).csv")

print(df.shape)
df.head()
# Out:
# (1000, 19)
#                                       title  magnitude         date_time  cdi  \
# 0          M 6.5 - 42 km W of Sola, Vanuatu        6.5  16-08-2023 12:47    7
# 1  M 6.5 - 43 km S of Intipucá, El Salvador        6.5  19-07-2023 00:22    8
# 2  M 6.6 - 25 km ESE of Loncopué, Argentina        6.6  17-07-2023 03:05    7
# 3     M 7.2 - 98 km S of Sand Point, Alaska        7.2  16-07-2023 06:48    6
# 4                  M 7.3 - Alaska Peninsula        7.3  16-07-2023 06:48    0
#
#    mmi   alert  tsunami  sig net  nst      dmin    gap magType    depth  \
# 0    4   green        0  657  us  114  7.177000   25.0     mww  192.955
# 1    6  yellow        0  775  us   92  0.679000   40.0     mww   69.727
# 2    5   green        0  899  us   70  1.634000   28.0     mww  171.371
# 3    6   green        1  860  us  173  0.907000   36.0     mww   32.571
# 4    5     NaN        1  820  at   79  0.879451  172.8      Mi   21.000
#
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
import matplotlib.cm as cm

plt.figure(figsize=(10, 6))

data = df['magnitude'].dropna()

counts, bins, patches = plt.hist(
    data,
    bins=20,
    edgecolor='black'
)

norm = Normalize(vmin=counts.min(), vmax=counts.max())

for count, patch in zip(counts, patches):
    patch.set_facecolor(cm.viridis(norm(count)))

sm = cm.ScalarMappable(norm=norm, cmap=cm.viridis)
sm.set_array([])

cbar = plt.colorbar(sm, ax=plt.gca())
cbar.set_label('Frequency')

plt.xlabel('Earthquake Magnitude')
plt.ylabel('Number of Earthquakes')
plt.title('Histogram of Earthquake Magnitudes')
plt.grid(axis='y', alpha=0.3)

plt.show()

# %%
import pandas as pd

df = pd.read_csv("/content/earthquake_1995-2023 (1).csv")

print("rows and coloumns:", df.shape)
df.head()     # show the first 5 rows
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_957/1156429435.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("/content/earthquake_1995-2023 (1).csv")
#       4
#       5 print("rows and coloumns:", df.shape)
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv("/content/earthquake_1995-2023 (3).csv")

# Count earthquakes for each country
data = df["country"].value_counts().head(10)

# Normalize values for colormap
norm = mpl.colors.Normalize(vmin=data.min(), vmax=data.max())

# Choose colormap
cmap = plt.cm.viridis

# Create colors based on bar height
colors = cmap(norm(data.values))

# Create bar plot
data.plot(kind="bar", color=colors)

# Add colorbar
sm = mpl.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.colorbar(sm, ax=plt.gca(), label="Number of Earthquakes")

plt.xlabel("Country")
plt.ylabel("Number of Earthquakes")
plt.title("Top 10 Countries by Number of Earthquakes")
plt.show()

# %%
import matplotlib.pyplot as plt

country_count = df['country'].value_counts().head(10)

plt.figure(figsize=(7,7))

plt.pie(
    country_count,
    labels=country_count.index,
    autopct='%1.1f%%',
    startangle=90
)

plt.title('Top 10 Countries with Earthquakes')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read CSV file
df = pd.read_csv("/content/earthquake_1995-2023 (5).csv")
# Convert date_time column to date format
df["date_time"] = pd.to_datetime(df["date_time"])

# Extract year
df["year"] = df["date_time"].dt.year

# Count earthquakes for each year
earthquakes_per_year = df["year"].value_counts().sort_index()

# Create line plot
plt.figure(figsize=(10, 5))

plt.plot(
    earthquakes_per_year.index,
    earthquakes_per_year.values,
    marker="o"
)

plt.xlabel("Year")
plt.ylabel("Number of Earthquakes")
plt.title("Number of Earthquakes per Year")
plt.grid(True)

plt.show()
# Out:
# /tmp/ipykernel_1986/4182348744.py:7: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["date_time"] = pd.to_datetime(df["date_time"])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read CSV file
df = pd.read_csv("/content/earthquake_1995-2023 (5).csv")

# Scatter plot
plt.figure(figsize=(10, 6))

plt.scatter(df["depth"], df["magnitude"])

plt.xlabel("Depth")
plt.ylabel("Magnitude")
plt.title("Earthquake Magnitude vs Depth")
plt.grid(True)

plt.show()
